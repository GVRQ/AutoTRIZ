# %% [markdown]
# # AI-агент для генерации AutoTRIZ
#
# Основан на

# %%
# === УСТАНОВКА ЗАВИСИМОСТЕЙ (Colab) ===
# !pip install gigachat langgraph langchain_gigachat langchain_tavily -q -U

# %%
# === CONFIG ===
import os
from google.colab import userdata

# Провайдер: 'gigachat' или 'openai'
PROVIDER = 'gigachat'

OPENAI_MODEL = 'gpt-4o-mini'
GIGACHAT_MODEL = 'GigaChat-2-Max'

credentials = None
if PROVIDER == 'openai':
    import getpass
    os.environ['OPENAI_API_KEY'] = getpass.getpass('Введите OPENAI_API_KEY: ')
elif PROVIDER == 'gigachat':
    # Берём ключ из Colab userdata (заранее добавьте в UI: Settings → User data → giga_key)
    credentials = userdata.get('giga_key')
    if not credentials:
        raise RuntimeError("Не найден userdata['giga_key']. Добавьте ключ в Colab (Settings → User data).")
    os.environ["GIGACHAT_BASE_URL"] = "https://gigachat.devices.sberbank.ru/api/v1"

# Опциональный ключ Tavily для поиска (по желанию можно оставить пустым в Settings → User data → tavily_key)
tavily_key = userdata.get('tavily_key')
if tavily_key:
    os.environ['TAVILY_API_KEY'] = tavily_key

MODEL_NAME = OPENAI_MODEL if PROVIDER == 'openai' else GIGACHAT_MODEL
print(f"Провайдер: {PROVIDER}, модель: {MODEL_NAME}")
# Out:
# Провайдер: gigachat, модель: GigaChat-2-Max

# %% [markdown]
# ## Библиотечные вспомогательные функции

# %%
from typing import Optional, Literal
from typing_extensions import TypedDict, Annotated
from pydantic import BaseModel, Field

from langgraph.graph import StateGraph, START, END
from langgraph.types import Command, interrupt
from langgraph.checkpoint.memory import MemorySaver

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser, PydanticOutputParser

# Провайдеры
try:
    from langchain_openai import ChatOpenAI
except Exception:
    ChatOpenAI = None

try:
    from langchain_gigachat import GigaChat
except Exception:
    GigaChat = None

# Поиск (через официальный tavily-python)
from langchain_tavily import TavilySearch

def get_llm_from_config(config):
    """Возвращает LLM на основе config['configurable'].
    Для GigaChat отключает SSL verify (verify_ssl_certs=False)."""
    provider = config.get('configurable', {}).get('provider', 'openai')
    model = config.get('configurable', {}).get('model', 'gpt-4o-mini')
    if provider == 'openai':
        if ChatOpenAI is None:
            raise RuntimeError("langchain-openai не установлен")
        return ChatOpenAI(model=model, temperature=0)
    elif provider == 'gigachat':
        if GigaChat is None:
            raise RuntimeError("langchain-gigachat не установлен")
        return GigaChat(
            credentials=credentials,
            model=model,
            profanity_check=False,
            top_p=0,
            timeout=120,
            verify_ssl_certs=False  # 🔑 отключаем проверку SSL
        )
    else:
        raise ValueError(f"Неизвестный провайдер: {provider}")

def tavily_search(query: str, max_results: int = 3) -> str:
    """Возвращает короткое резюме результатов поиска. Если ключа нет — graceful fallback."""
    try:
        key = os.environ.get("TAVILY_API_KEY")
        if not key:
            return f"Поиск недоступен (нет TAVILY_API_KEY). Запрос: {query}"
        client = TavilySearch(api_key=key)
        res = client.search(query=query, search_depth="advanced", max_results=max_results)
        items = res.get('results', [])
        lines = [f"- {it.get('title')}: {it.get('url')} — {it.get('content','')[:200]}..." for it in items]
        return "\n".join(lines) if lines else "Ничего релевантного не найдено."
    except Exception as e:
        return f"Поиск временно недоступен. Запрос: {query}. Ошибка: {e}"

# %% [markdown]
# ## Состояние, вспомогательные функции и универсальный запрос к LLM

# %%
class TRIZGraphState(TypedDict):
    """Состояние TRIZ-агента: T, C, I, S, плюс контекст и фидбек."""
    main_task: Annotated[str, "Основная задача/проблема от пользователя"]
    context_analysis: Optional[Annotated[str, "Анализ контекста и похожих решений"]]
    feedback: Optional[Annotated[str, "Фидбек пользователя"]]
    problem_definition: Optional[Annotated[str, "Четкое определение проблемы"]]
    contradictions: Optional[Annotated[str, "Выявленные противоречия"]]
    inventive_principles: Optional[Annotated[str, "Применимые изобретательские приемы"]]
    solution_concept: Optional[Annotated[str, "Концепция решения на основе ТРИЗ"]]

def state_to_string(state: TRIZGraphState) -> str:
    lines = []
    for field, annotation in TRIZGraphState.__annotations__.items():
        value = state.get(field, "")
        if value:
            desc = ""
            if hasattr(annotation, "__metadata__") and annotation.__metadata__:
                desc = annotation.__metadata__[0]
            lines.append(f"{desc} ({field}): {value}")
    return "\n".join(lines)

def ask_triz_llm(state: TRIZGraphState, question: str, context: str, config) -> str:
    TEMPLATE = """Ты – эксперт по ТРИЗ (теория решения изобретательских задач) и разработке AI-агентов.
Учитывай основную задачу (main_task), текущее состояние анализа и фидбек пользователя (если есть).

Контекст:
{context}

Состояние:
{state}

Вопрос: {question}

Отвечай четко и структурированно, применяя ТРИЗ и приводя обоснования.
"""
    prompt = ChatPromptTemplate.from_messages([("system", TEMPLATE)])
    llm = get_llm_from_config(config)
    chain = prompt | llm | StrOutputParser()
    return chain.invoke({"state": state_to_string(state), "question": question, "context": context})

# %% [markdown]
# ## Узлы графа: T → C → I → S

# %%
def problem_definition(state: TRIZGraphState, config):
    context = "Выявляем суть задачи и ограничения."
    result = ask_triz_llm(state, "Сформулируй проблему четко и конкретно. Что именно нужно улучшить или преодолеть?", context, config)
    return {"problem_definition": result}

def identify_contradictions(state: TRIZGraphState, config):
    context = "Определи ключевое противоречие (техническое или физическое)."
    result = ask_triz_llm(state, "Какие два параметра в конфликте? (формат: X vs Y)", context, config)
    return {"contradictions": result}

def apply_inventive_principles(state: TRIZGraphState, config):
    text = (state.get("contradictions", "") or "").lower()
    principles_map = {
        ("скорост", "качеств"): ["Дробление/Сегментация", "Локальное качество"],
        ("простот", "функцион"): ["Посредник", "Вынесение"],
        ("автоном", "контрол"): ["Обратная связь", "Иерархичность"],
        ("персонализ", "универс"): ["Предварительное действие", "Дробление/Сегментация"],
    }
    for (a, b), principles in principles_map.items():
        if a in text and b in text:
            return {"inventive_principles": "Рекомендуемые принципы: " + ", ".join(principles)}
    # fallback к LLM
    context = "Подбери 3–5 принципов из 40 ТРИЗ, объясни, как каждый снимает противоречие."
    question = "Какие принципы применимы и почему?"
    result = ask_triz_llm(state, question, context, config)
    return {"inventive_principles": result}

def generate_solution_concept(state: TRIZGraphState, config):
    context = "Синтез решения на основе выявленного противоречия и выбранных принципов."
    result = ask_triz_llm(state, "Предложи концепцию решения и объясни, как принципы помогают устранить конфликт.", context, config)
    return {"solution_concept": result}

# %% [markdown]
# ## Оценка качества решения и обратная связь

# %%
class QualityAssessment(BaseModel):
    chain_of_thoughts: str = Field(description="Ход рассуждений")
    solution_quality: str = Field(description="Качество решения (оценка)")
    is_satisfactory: bool = Field(description="Удовлетворяет ли решение требованиям?")
    improvement_suggestions: str = Field(description="Рекомендации по улучшению")

def check_solution_quality(state: TRIZGraphState, config) -> Command[Literal["get_feedback", "problem_definition"]]:
    if config.get('configurable', {}).get('skip_search', False):
        return Command(goto="get_feedback")
    search_query = f"{state['problem_definition']} AI agent solution"
    search_results = tavily_search(search_query, max_results=3)

    parser = PydanticOutputParser(pydantic_object=QualityAssessment)
    prompt = ChatPromptTemplate.from_messages([
        ("system", """Проанализируй качество решения по ТРИЗ, сравнив его с найденными аналогами.

Состояние:
{state}

Поиск (резюме):
{search_results}

Дай оценку (новизна, реализуемость, соответствие ТРИЗ, риски) и рекомендации.
{format_instructions}
""")
    ]).partial(format_instructions=parser.get_format_instructions())

    llm = get_llm_from_config(config)
    chain = prompt | llm | parser
    assessment = chain.invoke({"state": state_to_string(state), "search_results": search_results})

    context_analysis = (
        f"Поиск по '{search_query}':\n{search_results}\n\n"
        f"Оценка: {assessment.solution_quality}"
    )
    if assessment.is_satisfactory:
        return Command(update={"context_analysis": context_analysis}, goto="get_feedback")
    else:
        return Command(update={"context_analysis": context_analysis}, goto="problem_definition")

RedirectStep = Literal[
    "problem_definition",
    "identify_contradictions",
    "apply_inventive_principles",
    "generate_solution_concept",
    "__end__",
]

class UserFeedback(BaseModel):
    feedback: str = Field(description="Отзыв пользователя")
    next_step: RedirectStep = Field(description="Этап для доработки")
    is_done: bool = Field(description="Завершить ли анализ?")

def get_feedback(state: TRIZGraphState, config) -> Command[Literal[RedirectStep, END]]:
    if config.get('configurable', {}).get('need_interrupt', True):
        fb_text = interrupt(
            "Оцените решение и укажите, что доработать (или напишите 'Готово').\n"
            "1) Что изменить? 2) С какого этапа перезапустить? 3) Готово?\n"
        )
    else:
        fb_text = "Все устраивает."

    parser = PydanticOutputParser(pydantic_object=UserFeedback)
    prompt = ChatPromptTemplate.from_messages([
        ("system", """Проанализируй отзыв пользователя и реши дальнейшие действия.
Состояние:
{state}

Отзыв:
{feedback}

Определи: 1) что улучшить, 2) стартовый этап, 3) завершать ли анализ.
{format_instructions}
""")
    ]).partial(format_instructions=parser.get_format_instructions())

    llm = get_llm_from_config(config)
    chain = prompt | llm | parser
    result = chain.invoke({"state": state_to_string(state), "feedback": fb_text})

    if result.is_done:
        return Command(update={}, goto=END)
    else:
        return Command(update={"feedback": result.feedback}, goto=result.next_step)

# %% [markdown]
# ## Сборка графа и утилиты

# %%
class TRIZGraphConfig(BaseModel):
    need_interrupt: bool = True
    skip_search: bool = False
    provider: Literal['openai', 'gigachat'] = 'gigachat'
    model: str = MODEL_NAME

def create_triz_agent():
    # ВАЖНО: context_schema вместо устаревшего config_schema
    graph = StateGraph(TRIZGraphState, context_schema=TRIZGraphConfig)
    graph.add_node("problem_definition", problem_definition)
    graph.add_node("identify_contradictions", identify_contradictions)
    graph.add_node("apply_inventive_principles", apply_inventive_principles)
    graph.add_node("generate_solution_concept", generate_solution_concept)
    graph.add_node("check_solution_quality", check_solution_quality)
    graph.add_node("get_feedback", get_feedback)

    graph.add_edge(START, "problem_definition")
    graph.add_edge("problem_definition", "identify_contradictions")
    graph.add_edge("identify_contradictions", "apply_inventive_principles")
    graph.add_edge("apply_inventive_principles", "generate_solution_concept")
    graph.add_edge("generate_solution_concept", "check_solution_quality")

    memory = MemorySaver()
    return graph.compile(checkpointer=memory)

def generate_triz_report(state: TRIZGraphState) -> str:
    return f"""# ОТЧЕТ TRIZ-АНАЛИЗА

## 1. Исходная задача
{state.get('main_task', '—')}

## 2. Определение проблемы
{state.get('problem_definition', '—')}

## 3. Выявленное противоречие
{state.get('contradictions', '—')}

## 4. Изобретательские приемы
{state.get('inventive_principles', '—')}

## 5. Концепция решения
{state.get('solution_concept', '—')}

## 6. Контекстный анализ
{state.get('context_analysis', '—')}

## 7. Фидбек пользователя
{state.get('feedback', '—')}
"""

def collect_state_from_stream(app, inputs, config):
    """Выполняет граф, аккумулирует состояние и печатает узлы."""
    state = {"main_task": inputs["main_task"]}
    for event in app.stream(inputs, config=config):
        if isinstance(event, dict):
            for node, output in event.items():
                if node != "__interrupt__" and isinstance(output, dict):
                    state.update(output)
                    print(f"\n📋 {node}")
                    for k, v in output.items():
                        print(f"  - {k}:\n{v}\n")
    return state

# %% [markdown]
# ## Демонстрация: неинтерактивный прогон

# %%
problem = "Мы хотим ускорить отклик мультиагентной системы, не снижая качество решений."

config = {
    "configurable": {
        "need_interrupt": False,
        "skip_search": True,           # можно True, если не нужен поиск
        "provider": PROVIDER,
        "model": MODEL_NAME,
        "thread_id": "demo-run-1",     # обязательно для MemorySaver
        "checkpoint_ns": "triz-demo"
    }
}

app = create_triz_agent()
state = collect_state_from_stream(app, {"main_task": problem}, config)
print("\n" + "-"*80 + "\nИтоговый отчет:\n")
print(generate_triz_report(state))
# Out:
# 📋 problem_definition
#   - problem_definition:
# **Формулировка проблемы:**
# Необходимо повысить скорость отклика мультиагентной системы, сохранив высокое качество принимаемых решений.
#
# ---
#
# ### **Анализ ситуации через призму ТРИЗ**
# 1. **Противоречие**:
#    Чем быстрее система принимает решение, тем ниже вероятность тщательного анализа всех факторов и выбора оптимального варианта. И наоборот — повышение качества требует больше времени на обработку информации и принятие взвешенного решения.
#
# 2. **Идеальное конечное решение (ИКР)**:
#    Система должна мгновенно принимать качественные решения без увеличения вычислительных ресурсов и снижения точности.
#
# 3. **Ограничения и ресурсы**:
#    - Ограничение по ресурсам (вычислительные мощности ограничены).
#    - Необходимость сохранения высокого уровня надежности и устойчивости решений.
#    - Требование минимизации задержек между получением запроса и выдачей результата.
#
# 4. **Инструменты ТРИЗ для преодоления противоречия**:
#    - Принцип разделения во времени («разделяй и властвуй») — разделение процесса принятия решений на несколько этапов, выполняющихся параллельно.
#    - Использование принципа предварительного исполнения действий — предварительная подготовка возможных сценариев развития событий до получения реального запроса.
#    - Применение принципа динамичности — адаптация алгоритмов работы агентов в зависимости от текущей нагрузки и сложности запросов.
#
# 5. **Возможные направления улучшения**:
#    - Оптимизация архитектуры взаимодействия агентов (уменьшение количества промежуточных шагов коммуникации).
#    - Внедрение механизма предиктивного анализа ситуаций для сокращения времени реакции.
#    - Повышение эффективности обработки входящей информации путем фильтрации нерелевантных данных.
#
# ---
#
# Таким образом, сформулированная проблема звучит следующим образом:
# «Повысить быстроту отклика мультиагентной системы без ущерба качеству решений».
#
#
# 📋 identify_contradictions
#   - contradictions:
# Ключевое техническое противоречие формулируется следующим образом:
#
# **Параметры конфликта:**
# - Быстрота отклика (X)
# vs
# - Качество решений (Y)
#
# **Обоснование:**
# При повышении скорости отклика (параметр X) снижается время на детальную оценку ситуации и выбор наилучшего решения, что ведет к снижению качества решений (параметр Y). С другой стороны, стремление сохранить высокое качество решений (параметр Y) требует большего времени на анализ и вычисления, замедляя реакцию системы (параметр X).
#
# Это классическое противоречие типа «быстро, но плохо» против «медленно, зато качественно», которое решается методами ТРИЗ через выявление идеального конечного состояния и применение соответствующих инструментов устранения противоречий.
#
#
# 📋 apply_inventive_principles
#   - inventive_principles:
# Рекомендуемые принципы: Дробление/Сегментация, Локальное качество
#
#
# 📋 generate_solution_concept
#   - solution_concept:
# ## Концепция решения на основе принципов ТРИЗ
#
# Для устранения технического противоречия между скоростью отклика и качеством решений предлагаем следующую концепцию, основанную на принципах дробления/сегментации и локального качества.
#
# ---
#
# ### **Принцип №1: Дробление / сегментация**
# Разделим процесс принятия решений на отдельные этапы и распределим их выполнение среди различных специализированных агентов. Это позволит одновременно обрабатывать разные аспекты задачи, ускорив общий цикл принятия решений.
#
# #### Как работает?
# - Разделение общей задачи на мелкие подзадачи, каждая из которых выполняется специализированным агентом.
# - Параллельная обработка нескольких аспектов задачи позволяет сократить общее время выполнения.
#
# #### Пример реализации:
# - Агенты разделяются на группы: одни отвечают за сбор и первичную фильтрацию данных, другие занимаются прогнозированием и оценкой рисков, третьи принимают финальное решение.
# - Каждый этап проходит параллельно, обеспечивая быстрое получение итогового результата.
#
# ---
#
# ### **Принцип №2: Локальное качество**
# Используем подход адаптивной настройки каждого агента под конкретную ситуацию, чтобы оптимизировать производительность именно там, где она наиболее важна.
#
# #### Как работает?
# - Настройка поведения агентов таким образом, чтобы каждый элемент системы работал эффективно именно в своей области ответственности.
# - Например, один агент быстро обрабатывает стандартные запросы, другой занимается сложными случаями, требующими глубокого анализа.
#
# #### Пример реализации:
# - Для простых и типовых запросов используются быстрые эвристические методы принятия решений.
# - Сложные случаи передаются специальным аналитическим агентам, обладающим большими ресурсами и временем на глубокий анализ.
#
# ---
#
# ### **Объединенный эффект двух принципов**
# Применение обоих принципов совместно устраняет основное противоречие:
# - Благодаря принципу дробления сокращается время ожидания результатов благодаря параллельному выполнению операций.
# - За счет принципа локального качества повышается эффективность отдельных элементов системы, позволяя каждому агенту сосредоточиться на своем узком сегменте задач.
#
# ---
#
# ### Итоговая концепция:
# Система состоит из множества специализированных агентов, работающих параллельно над разными частями задачи. Простые запросы решаются быстро и автоматически, сложные — направляются на углубленный анализ. Такой подход обеспечивает высокую скорость отклика без потери качества решений.
#
# ---
#
# ### Преимущества предложенной концепции:
# - Сокращение общего времени отклика за счет параллельной обработки.
# - Сохранение высокого качества решений благодаря специализации агентов.
# - Эффективное использование имеющихся вычислительных мощностей.
#
# Таким образом, синтезируя два указанных принципа, мы устраняем исходное противоречие и приближаемся к идеальному конечному результату — мгновенному принятию качественных решений.
#
#
# --------------------------------------------------------------------------------
# Итоговый отчет:
#
# # ОТЧЕТ TRIZ-АНАЛИЗА
#
# ## 1. Исходная задача
# Мы хотим ускорить отклик мультиагентной системы, не снижая качество решений.
#
# ## 2. Определение проблемы
# **Формулировка проблемы:**
# Необходимо повысить скорость отклика мультиагентной системы, сохранив высокое качество принимаемых решений.
#
# ---
#
# ### **Анализ ситуации через призму ТРИЗ**
# 1. **Противоречие**:
#    Чем быстрее система принимает решение, тем ниже вероятность тщательного анализа всех факторов и выбора оптимального варианта. И наоборот — повышение качества требует больше времени на обработку информации и принятие взвешенного решения.
#
# 2. **Идеальное конечное решение (ИКР)**:
#    Система должна мгновенно принимать качественные решения без увеличения вычислительных ресурсов и снижения точности.
#
# 3. **Ограничения и ресурсы**:
#    - Ограничение по ресурсам (вычислительные мощности ограничены).
#    - Необходимость сохранения высокого уровня надежности и устойчивости решений.
#    - Требование минимизации задержек между получением запроса и выдачей результата.
#
# 4. **Инструменты ТРИЗ для преодоления противоречия**:
#    - Принцип разделения во времени («разделяй и властвуй») — разделение процесса принятия решений на несколько этапов, выполняющихся параллельно.
#    - Использование принципа предварительного исполнения действий — предварительная подготовка возможных сценариев развития событий до получения реального запроса.
#    - Применение принципа динамичности — адаптация алгоритмов работы агентов в зависимости от текущей нагрузки и сложности запросов.
#
# 5. **Возможные направления улучшения**:
#    - Оптимизация архитектуры взаимодействия агентов (уменьшение количества промежуточных шагов коммуникации).
#    - Внедрение механизма предиктивного анализа ситуаций для сокращения времени реакции.
#    - Повышение эффективности обработки входящей информации путем фильтрации нерелевантных данных.
#
# ---
#
# Таким образом, сформулированная проблема звучит следующим образом:
# «Повысить быстроту отклика мультиагентной системы без ущерба качеству решений».
#
# ## 3. Выявленное противоречие
# Ключевое техническое противоречие формулируется следующим образом:
#
# **Параметры конфликта:**
# - Быстрота отклика (X)
# vs
# - Качество решений (Y)
#
# **Обоснование:**
# При повышении скорости отклика (параметр X) снижается время на детальную оценку ситуации и выбор наилучшего решения, что ведет к снижению качества решений (параметр Y). С другой стороны, стремление сохранить высокое качество решений (параметр Y) требует большего времени на анализ и вычисления, замедляя реакцию системы (параметр X).
#
# Это классическое противоречие типа «быстро, но плохо» против «медленно, зато качественно», которое решается методами ТРИЗ через выявление идеального конечного состояния и применение соответствующих инструментов устранения противоречий.
#
# ## 4. Изобретательские приемы
# Рекомендуемые принципы: Дробление/Сегментация, Локальное качество
#
# ## 5. Концепция решения
# ## Концепция решения на основе принципов ТРИЗ
#
# Для устранения технического противоречия между скоростью отклика и качеством решений предлагаем следующую концепцию, основанную на принципах дробления/сегментации и локального качества.
#
# ---
#
# ### **Принцип №1: Дробление / сегментация**
# Разделим процесс принятия решений на отдельные этапы и распределим их выполнение среди различных специализированных агентов. Это позволит одновременно обрабатывать разные аспекты задачи, ускорив общий цикл принятия решений.
#
# #### Как работает?
# - Разделение общей задачи на мелкие подзадачи, каждая из которых выполняется специализированным агентом.
# - Параллельная обработка нескольких аспектов задачи позволяет сократить общее время выполнения.
#
# #### Пример реализации:
# - Агенты разделяются на группы: одни отвечают за сбор и первичную фильтрацию данных, другие занимаются прогнозированием и оценкой рисков, третьи принимают финальное решение.
# - Каждый этап проходит параллельно, обеспечивая быстрое получение итогового результата.
#
# ---
#
# ### **Принцип №2: Локальное качество**
# Используем подход адаптивной настройки каждого агента под конкретную ситуацию, чтобы оптимизировать производительность именно там, где она наиболее важна.
#
# #### Как работает?
# - Настройка поведения агентов таким образом, чтобы каждый элемент системы работал эффективно именно в своей области ответственности.
# - Например, один агент быстро обрабатывает стандартные запросы, другой занимается сложными случаями, требующими глубокого анализа.
#
# #### Пример реализации:
# - Для простых и типовых запросов используются быстрые эвристические методы принятия решений.
# - Сложные случаи передаются специальным аналитическим агентам, обладающим большими ресурсами и временем на глубокий анализ.
#
# ---
#
# ### **Объединенный эффект двух принципов**
# Применение обоих принципов совместно устраняет основное противоречие:
# - Благодаря принципу дробления сокращается время ожидания результатов благодаря параллельному выполнению операций.
# - За счет принципа локального качества повышается эффективность отдельных элементов системы, позволяя каждому агенту сосредоточиться на своем узком сегменте задач.
#
# ---
#
# ### Итоговая концепция:
# Система состоит из множества специализированных агентов, работающих параллельно над разными частями задачи. Простые запросы решаются быстро и автоматически, сложные — направляются на углубленный анализ. Такой подход обеспечивает высокую скорость отклика без потери качества решений.
#
# ---
#
# ### Преимущества предложенной концепции:
# - Сокращение общего времени отклика за счет параллельной обработки.
# - Сохранение высокого качества решений благодаря специализации агентов.
# - Эффективное использование имеющихся вычислительных мощностей.
#
# Таким образом, синтезируя два указанных принципа, мы устраняем исходное противоречие и приближаемся к идеальному конечному результату — мгновенному принятию качественных решений.
#
# ## 6. Контекстный анализ
# —
#
# ## 7. Фидбек пользователя
# —

# %% [markdown]
# ## Демонстрация: интерактивный режим (interrupt/resume)
# Выполните ячейку: агент остановится на этапе обратной связи и спросит комментарии.
# Введите ответ прямо в консоли ячейки (например: «Добавить кэширование; начать с противоречий»).
# Чтобы завершить — напишите «Готово».

# %%
problem = "Нужно повысить пропускную способность API-инструментов агента без ухудшения надежности."
config = {
    "configurable": {
        "need_interrupt": True,
        "skip_search": False,          # поставьте True, если нет TAVILY_API_KEY
        "provider": PROVIDER,
        "model": MODEL_NAME,
        "thread_id": "demo-run-2",
        "checkpoint_ns": "triz-demo"
    }
}

app = create_triz_agent()
inputs = {"main_task": problem}
print("🔧 Запуск интерактивного анализа...")

for event in app.stream(inputs, config=config):
    if isinstance(event, dict):
        for node, output in event.items():
            if node != "__interrupt__" and isinstance(output, dict):
                print(f"\n📋 {node}")
                for k, v in output.items():
                    print(f"  - {k}:\n{v}\n")

while '__interrupt__' in event:
    prompt_text = event['__interrupt__'][0].value
    print("\n⚠️ Запрос фидбека:\n" + prompt_text)
    user_input = input("Ваш ответ: ")
    for event in app.stream(Command(resume=user_input), config=config):
        if isinstance(event, dict):
            for node, output in event.items():
                if node != "__interrupt__" and isinstance(output, dict):
                    print(f"\n📋 {node}")
                    for k, v in output.items():
                        print(f"  - {k}:\n{v}\n")
print("\nГотово.")
# Out:
# 🔧 Запуск интерактивного анализа...
#
# 📋 problem_definition
#   - problem_definition:
# **Формулировка проблемы:**
# Необходимо увеличить количество запросов, обрабатываемых агентом через API-интерфейсы, сохраняя высокую надежность системы и качество обработки каждого запроса.
#
# **Конкретизация требований:**
# 1. **Пропускная способность**: Увеличение количества одновременно выполняемых запросов без перегрузки инфраструктуры и снижения производительности.
# 2. **Надежность**: Сохранение высокой доступности сервиса даже при увеличении нагрузки — минимизация отказов и ошибок.
# 3. **Качество обработки**: Обеспечение корректности выполнения всех операций независимо от объема поступающих запросов.
# 4. **Масштабируемость**: Возможность быстрого масштабирования ресурсов при росте числа пользователей и интенсивности работы.
# 5. **Эффективное использование ресурсов**: Оптимальное распределение вычислительных мощностей между различными компонентами системы.
#
# **Ограничения и противоречия:**
# - Чем больше запросов поступает, тем сложнее поддерживать стабильный уровень качества обработки и избегать деградации производительности.
# - Повышение пропускной способности требует увеличения аппаратных ресурсов, что ведет к росту затрат и усложнению управления инфраструктурой.
# - Необходимость обеспечения безопасности и защиты данных ограничивает возможности оптимизации скорости обработки запросов.
#
# **Цель формулировки:**
# Четко обозначенная проблема позволит выявить ключевые технические аспекты, влияющие на производительность и надежность, и определить направления поиска решений методами ТРИЗ (например, применение принципа разделения функций, идеального конечного результата).
#
#
# 📋 identify_contradictions
#   - contradictions:
# Ключевое техническое противоречие здесь следующее:
#
# ### Формулировка конфликта:
# **Повышенная пропускная способность (X)** vs **Высокая надежность (Y)**.
#
# ---
#
# ### Обоснование:
# При повышении пропускной способности увеличивается нагрузка на систему, что потенциально снижает её надёжность:
# - Рост числа одновременных запросов повышает риск возникновения узких мест и перегрузок отдельных компонентов.
# - Усложняется контроль над качеством обработки каждого отдельного запроса, возрастает вероятность сбоев и ошибок.
# - Требуется дополнительное оборудование и ресурсы, что увеличивает сложность архитектуры и затраты на управление системой.
#
# Таким образом, повышение одного параметра (пропускной способности) негативно влияет на другой параметр (надежность). Это классическое техническое противоречие, которое решается методами ТРИЗ путём выявления и устранения корневых причин конфликта.
#
#
# 📋 apply_inventive_principles
#   - inventive_principles:
# Для повышения пропускной способности API-инструментов агента без ущерба для надежности воспользуемся подходами теории решения изобретательских задач (ТРИЗ):
#
# ## Применимые принципы ТРИЗ
#
# ### Принцип №7: ПЕРЕХОД В ДРУГОЙ РАЗМЕРНОСТЬ
# **Описание:** Решение проблемы путем перехода от одномерного пространства к двумерному или трехмерному, либо наоборот.
#
# **Применение:** Вместо линейного расширения серверов (увеличение мощности одной машины), использовать горизонтальное масштабирование (распределенные кластеры). Таким образом, запросы распределяются равномерно среди множества узлов, снижая нагрузку на отдельные компоненты и повышая общую устойчивость системы.
#
# **Результат:** Пропускная способность растет пропорционально количеству машин, надежность сохраняется благодаря распределенной архитектуре.
#
# ---
#
# ### Принцип №8: АНТИ-ВЕСА ИЛИ ПРОТИВОДЕЙСТВИЕ
# **Описание:** Использование противоположных сил или свойств для компенсации негативных эффектов.
#
# **Применение:** Для предотвращения перегрузки сервера при резком всплеске активности внедрить механизм автоматического балансировки нагрузки (load balancing). Если один узел испытывает повышенную нагрузку, система автоматически перераспределяет запросы на менее загруженные узлы.
#
# **Результат:** Система становится устойчивее к пиковым нагрузкам, обеспечивая равномерную обработку запросов и предотвращая снижение надежности.
#
# ---
#
# ### Принцип №9: ОБЪЕДИНЕНИЕ ПОТОКОВ
# **Описание:** Объединение потоков энергии, вещества или информации для достижения синергетического эффекта.
#
# **Применение:** Реализовать асинхронную обработку запросов с использованием очередей сообщений (message queues). Запросы поступают в очередь и обрабатываются параллельно несколькими серверами, что позволяет эффективно справляться с большими объемами входящего трафика.
#
# **Результат:** Снижение задержки обработки запросов, увеличение общей пропускной способности без потери надежности.
#
# ---
#
# ### Принцип №16: ЧАСТИЧНОЕ ИЛИ ЧРЕЗМЕРНОЕ РЕШЕНИЕ
# **Описание:** Частичное решение проблемы может оказаться достаточным решением, а чрезмерное решение иногда оказывается оптимальным вариантом.
#
# **Применение:** Использовать кэширование часто запрашиваемых данных (API-кэширование). Кэшированные результаты позволяют быстро отвечать на повторяющиеся запросы, уменьшая нагрузку на основной сервер и увеличивая скорость отклика.
#
# **Результат:** Значительное уменьшение нагрузки на инфраструктуру, ускорение обработки типичных запросов и сохранение высокого уровня надежности.
#
# ---
#
# Эти принципы помогают устранить ключевое противоречие между повышением пропускной способности и сохранением надежности, предлагая конкретные инженерные подходы для реализации эффективного и надежного API-сервиса.
#
#
# 📋 generate_solution_concept
#   - solution_concept:
# # Концепция решения на основе методов ТРИЗ
#
# Для повышения пропускной способности API-инструментов агента без ущерба для надежности предлагается следующая концепция решения, основанная на принципах ТРИЗ:
#
# ## Основные элементы концепции:
#
# ### 1. Горизонтальное масштабирование (Принцип №7)
# - **Решение:** Переход от вертикальной модели роста (усиление мощности одного узла) к горизонтальному масштабированию (создание распределенного кластера серверов).
# - **Обоснование:** Распределённая архитектура обеспечивает равномерное распределение нагрузки между множеством узлов, устраняя проблему перегрузки отдельных элементов и поддерживая стабильность системы при высоких нагрузках.
#
# ### 2. Автоматическая балансировка нагрузки (Принцип №8)
# - **Решение:** Применение механизма автоматической балансировки нагрузки (load balancer), который динамически перенаправляет запросы на наименее загруженные серверы.
# - **Обоснование:** Балансировщик предотвращает возникновение узких мест и гарантирует равномерную загрузку всех узлов, улучшая общую эффективность и надежность системы.
#
# ### 3. Асинхронная обработка запросов (Принцип №9)
# - **Решение:** Организация очереди сообщений (message queue) для буферизации входящих запросов и параллельной обработки нескольких запросов одновременно.
# - **Обоснование:** Очереди обеспечивают плавное поглощение пикового трафика, позволяя обрабатывать большое число запросов без замедления или отказа системы.
#
# ### 4. Кэширование результатов (Принцип №16)
# - **Решение:** Создание многоуровневого кэша для хранения наиболее востребованных данных и результатов вычислений.
# - **Обоснование:** Кэширование уменьшает необходимость повторного обращения к источникам данных, сокращает время реакции на частые запросы и разгружает основные серверы, способствуя повышению пропускной способности и стабильности системы.
#
# ## Как принципы ТРИЗ устраняют конфликт?
#
# | Противоречие | Метод разрешения |
# |---------------|------------------|
# | Высокая пропускная способность против надежности | Горизонтальное масштабирование устраняет зависимость между количеством запросов и нагрузкой на отдельный узел, обеспечивая рост пропускной способности без риска падения надежности. |
# | Перегрузка системы при большом числе запросов | Автоматическая балансировка нагрузки компенсирует неравномерность распределения запросов, исключая возможность перегрузки отдельных узлов. |
# | Задержки обработки при больших объёмах запросов | Асинхронная обработка и очереди сообщений сглаживают влияние пиковых нагрузок, гарантируя своевременную обработку запросов. |
# | Повторяющиеся запросы увеличивают нагрузку на серверы | Кэширование снимает избыточную нагрузку, предоставляя быстрые ответы на часто встречающиеся запросы без дополнительной обработки. |
#
# ## Итоговая схема решения:
#
# ```
# +-----------+
# | Пользователь отправляет запрос → |
# +-----------+
#            ↓
# +-----------+
# | Load Balancer (балансировка нагрузки) |
# +-----------+
#            ↓
# +-----------+
# | Message Queue (очередь сообщений)   |
# +-----------+
#            ↓
# +-----------+
# | Cluster of Servers (горизонтально масштабированная инфраструктура) |
# +-----------+
#            ↓
# +-----------+
# | Cache Layer (многослойный кэш)       |
# +-----------+
#            ↓
# +-----------+
# | Ответ возвращается пользователю     |
# +-----------+
# ```
#
# Эта структура решает основное противоречие, обеспечивая высокий уровень пропускной способности при сохранении надежной и эффективной работы системы.
#
#
# 📋 check_solution_quality
#   - context_analysis:
# Поиск по '**Формулировка проблемы:**
# Необходимо увеличить количество запросов, обрабатываемых агентом через API-интерфейсы, сохраняя высокую надежность системы и качество обработки каждого запроса.
#
# **Конкретизация требований:**
# 1. **Пропускная способность**: Увеличение количества одновременно выполняемых запросов без перегрузки инфраструктуры и снижения производительности.
# 2. **Надежность**: Сохранение высокой доступности сервиса даже при увеличении нагрузки — минимизация отказов и ошибок.
# 3. **Качество обработки**: Обеспечение корректности выполнения всех операций независимо от объема поступающих запросов.
# 4. **Масштабируемость**: Возможность быстрого масштабирования ресурсов при росте числа пользователей и интенсивности работы.
# 5. **Эффективное использование ресурсов**: Оптимальное распределение вычислительных мощностей между различными компонентами системы.
#
# **Ограничения и противоречия:**
# - Чем больше запросов поступает, тем сложнее поддерживать стабильный уровень качества обработки и избегать деградации производительности.
# - Повышение пропускной способности требует увеличения аппаратных ресурсов, что ведет к росту затрат и усложнению управления инфраструктурой.
# - Необходимость обеспечения безопасности и защиты данных ограничивает возможности оптимизации скорости обработки запросов.
#
# **Цель формулировки:**
# Четко обозначенная проблема позволит выявить ключевые технические аспекты, влияющие на производительность и надежность, и определить направления поиска решений методами ТРИЗ (например, применение принципа разделения функций, идеального конечного результата). AI agent solution':
# Поиск временно недоступен. Запрос: **Формулировка проблемы:**
# Необходимо увеличить количество запросов, обрабатываемых агентом через API-интерфейсы, сохраняя высокую надежность системы и качество обработки каждого запроса.
#
# **Конкретизация требований:**
# 1. **Пропускная способность**: Увеличение количества одновременно выполняемых запросов без перегрузки инфраструктуры и снижения производительности.
# 2. **Надежность**: Сохранение высокой доступности сервиса даже при увеличении нагрузки — минимизация отказов и ошибок.
# 3. **Качество обработки**: Обеспечение корректности выполнения всех операций независимо от объема поступающих запросов.
# 4. **Масштабируемость**: Возможность быстрого масштабирования ресурсов при росте числа пользователей и интенсивности работы.
# 5. **Эффективное использование ресурсов**: Оптимальное распределение вычислительных мощностей между различными компонентами системы.
#
# **Ограничения и противоречия:**
# - Чем больше запросов поступает, тем сложнее поддерживать стабильный уровень качества обработки и избегать деградации производительности.
# - Повышение пропускной способности требует увеличения аппаратных ресурсов, что ведет к росту затрат и усложнению управления инфраструктурой.
# - Необходимость обеспечения безопасности и защиты данных ограничивает возможности оптимизации скорости обработки запросов.
#
# **Цель формулировки:**
# Четко обозначенная проблема позволит выявить ключевые технические аспекты, влияющие на производительность и надежность, и определить направления поиска решений методами ТРИЗ (например, применение принципа разделения функций, идеального конечного результата). AI agent solution. Ошибка: 'TavilySearch' object has no attribute 'search'
#
# Оценка: Предложенное решение качественно соответствует методологии ТРИЗ и демонстрирует глубокое понимание технических аспектов проблемы. Оно предлагает комплекс мер, направленных на улучшение пропускной способности без ущерба для надежности. Однако стоит учитывать возможные дополнительные сложности, такие как синхронизация состояния между узлами, обеспечение согласованности данных и потенциальные ограничения масштабируемости при дальнейшем росте нагрузки.
#
#
# ⚠️ Запрос фидбека:
# Оцените решение и укажите, что доработать (или напишите 'Готово').
# 1) Что изменить? 2) С какого этапа перезапустить? 3) Готово?
#
# Ваш ответ: 3
#
# Готово.

# %% [markdown]
# ## Быстрый однопроходный TRIZ-анализ (необязательно)

# %%
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

prompt = PromptTemplate.from_template("""Проведи быстрый TRIZ-анализ:
{problem}

Ответь по структуре:
1) Противоречие
2) 3–5 применимых изобретательских приемов
3) Концепция решения
""")
llm = get_llm_from_config({"configurable": {"provider": PROVIDER, "model": MODEL_NAME}})
print((prompt | llm | StrOutputParser()).invoke({"problem": "Оптимизировать стоимость инференса без падения качества"}))
# Out:
# ### Анализ по методологии ТРИЗ (Теория Решения Изобретательских Задач)
#
# #### 1. Противоречие
# Необходимо снизить затраты на проведение инференса модели машинного обучения, сохранив высокое качество результатов. Чем больше ресурсов выделяется на вычисления — тем лучше точность прогноза, однако растут расходы. Снижение вычислительных затрат ведет к ухудшению точности предсказания.
#
# **Противоречие:** высокая производительность требует больших расходов → снижение стоимости снижает качество работы модели.
#
# ---
#
# #### 2. Применимые приемы:
# - **Принцип дробления**: разделить процесс инференса на несколько этапов, оптимизируя каждый отдельно (например, предварительная фильтрация входных данных).
# - **Принцип динамичности**: адаптивная настройка сложности моделей в зависимости от конкретных запросов пользователей (менее требовательные запросы обрабатываются упрощенными моделями).
# - **Принцип перехода в другое измерение**: использование распределенных облачных решений или гибридных архитектур (локальные + удаленные серверы), чтобы перераспределять нагрузку между ресурсами разной мощности.
# - **Принцип посредника**: внедрение промежуточной системы предварительной обработки данных перед подачей на основную модель (предварительное сжатие изображений, текста и др.).
# - **Принцип обратимости**: использовать обратную связь от конечного результата для оптимизации последующих запросов (обучение модели на основе реальных ошибок и улучшений).
#
# ---
#
# #### 3. Концепция решения
# Для снижения стоимости инференса без потери качества предлагается внедрить систему многоуровневого анализа данных:
#
# 1. **Предварительный этап быстрой оценки**. Простая модель быстро оценивает сложность запроса и определяет необходимость дальнейшей глубокой обработки.
#
# 2. **Адаптивное распределение нагрузки**. В зависимости от уровня сложности запроса выбираются разные ресурсы для выполнения инференса: менее сложные запросы отправляются на недорогие локальные устройства, более сложные — на мощные облачные сервера.
#
# 3. **Обратная связь и обучение**. Система постоянно собирает данные о качестве прогнозов и автоматически корректирует параметры распределения нагрузок и настройки моделей.
#
# Таким образом, достигается баланс между стоимостью и качеством путем гибкого управления ресурсами и интеллектуального выбора подходящих инструментов для каждого конкретного случая.
